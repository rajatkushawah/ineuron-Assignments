# %% [markdown]
# que1- What does RGBA stand for?

# %% [markdown]
# ans1- RGBA color values are an extension of RGB color values with an alpha channel - which specifies the opacity for a color. An RGBA color value is specified with: rgba(red, green, blue, alpha).

# %% [markdown]
# que2- From the Pillow module, how do you get the RGBA value of any images?

# %% [markdown]
# ans2- A function call to ImageColor.getcolor('CornflowerBlue', 'RGBA') will return (100, 149, 237, 255), the RGBA value for that color.

# %% [markdown]
# que3- What is a box tuple, and how does it work?

# %% [markdown]
# ans3- A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height, respectively.

# %% [markdown]
# que4- Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %% [markdown]
# ans4-

# %%
from PIL import Image
img = Image.open('image.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x9F426EFDF0>

# %%
img.size
# Out:
# (1920, 1080)

# %% [markdown]
# que5- What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# ans5- img.crop((0, 50, 50, 50))

# %% [markdown]
# que6- After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# ans6- Call the img.save('newimg.jpg') method of the Image object.

# %% [markdown]
# que7- What module contains Pillow’s shape-drawing code?

# %% [markdown]
# ans7- The ImageDraw module contains code to draw on images.

# %% [markdown]
# que8- Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# ans8- ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function.
